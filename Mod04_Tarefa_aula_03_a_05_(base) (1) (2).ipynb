# %% [markdown]
# ## Exercício 1: Vestibular
#
# Considere que a os dados gerados na célula abaixo contêm o número de acertos de 100 alunos em um vestibular para um curso de exatas, divididas pelos respectivos assuntos. Considere que cada assunto possui um número de questões conforme a tabela abaixo:
#
# | assunto | número de questões |
# |:---:|:---:|
# | Matemática | 24 |
# | Português | 18 |
# | Geografia | 8 |
# | Inglês | 8 |
# | História | 8 |
# | Física | 12 |
# | Química | 12 |
#
# Usando os comandos de operações com DataFrames que você aprendeu na Aula 03, calcule:
#
# 1. (operações com escalar) Calcule o percentual de acerto dos alunos por assunto.
# 2. (operações entre *DataFrames) Calcule o total de acertos de cada aluno.
# 3. Calcule o porcentual geral de cada aluno.
# 4. Suponha que a nota de corte para a segunda fase seja 45. Quantos alunos tiveram nota maior que 45?

# %%
import pandas as pd
import numpy as np

np.random.seed(42)
df_mat = pd.DataFrame(np.random.randint(24, size=(100, 1)), columns=['Qt_acertos'])

df_por = pd.DataFrame(np.random.randint(18, size=(100, 1)), columns=['Qt_acertos'])

df_geo = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_ing = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_his = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_fis = pd.DataFrame(np.random.randint(12, size=(100, 1)), columns=['Qt_acertos'])

df_qui = pd.DataFrame(np.random.randint(12, size=(100, 1)), columns=['Qt_acertos'])

# %%
# 1) Seu código aqui
n_quest = [24,18,8,8,8,12,12]

df_mat['media']=df_mat['Qt_acertos']/n_quest[0]
df_por['media']=df_por['Qt_acertos']/n_quest[1]
df_geo['media']=df_geo['Qt_acertos']/n_quest[2]
df_ing['media']=df_ing['Qt_acertos']/n_quest[3]
df_his['media']=df_his['Qt_acertos']/n_quest[4]
df_fis['media']=df_fis['Qt_acertos']/n_quest[5]
df_qui['media']=df_qui['Qt_acertos']/n_quest[0]
df_mat
# Out:
#     Qt_acertos     media
# 0            6  0.250000
# 1           19  0.791667
# 2           14  0.583333
# 3           10  0.416667
# 4            7  0.291667
# ..         ...       ...
# 95           6  0.250000
# 96           8  0.333333
# 97          23  0.958333
# 98           0  0.000000
# 99          11  0.458333
#
# [100 rows x 2 columns]

# %%
# 2) Seu código aqui
df_tot_acert= pd.DataFrame()
df_tot_acert['Total de Acertos'] = df_mat['Qt_acertos']+df_por['Qt_acertos']+df_geo['Qt_acertos']+df_ing['Qt_acertos']+df_his['Qt_acertos']+df_fis['Qt_acertos']+df_qui['Qt_acertos']
df_tot_acert
# Out:
#     Total de Acertos
# 0                 35
# 1                 48
# 2                 50
# 3                 32
# 4                 30
# ..               ...
# 95                34
# 96                27
# 97                40
# 98                40
# 99                42
#
# [100 rows x 1 columns]

# %%
# 3) Seu código aqui
df_tot_acert['Porcentual Geral'] = df_tot_acert['Total de Acertos']/90
df_tot_acert
# Out:
#     Total de Acertos  Porcentual Geral
# 0                 35          0.388889
# 1                 48          0.533333
# 2                 50          0.555556
# 3                 32          0.355556
# 4                 30          0.333333
# ..               ...               ...
# 95                34          0.377778
# 96                27          0.300000
# 97                40          0.444444
# 98                40          0.444444
# 99                42          0.466667
#
# [100 rows x 2 columns]

# %%
# 4) Seu código aqui

df_tot_acert.loc[(df_tot_acert['Total de Acertos'] >= 45, 'Resultado')]= 'Aprovado'
df_tot_acert.loc[(df_tot_acert['Total de Acertos'] < 45, 'Resultado')]= 'Reprovado'
df_tot_acert
# Out:
#     Total de Acertos  Porcentual Geral  Resultado
# 0                 35          0.388889  Reprovado
# 1                 48          0.533333   Aprovado
# 2                 50          0.555556   Aprovado
# 3                 32          0.355556  Reprovado
# 4                 30          0.333333  Reprovado
# ..               ...               ...        ...
# 95                34          0.377778  Reprovado
# 96                27          0.300000  Reprovado
# 97                40          0.444444  Reprovado
# 98                40          0.444444  Reprovado
# 99                42          0.466667  Reprovado
#
# [100 rows x 3 columns]

# %% [markdown]
# ## 2) Vestibular II
#
# Ainda sobre o mesmo banco de dados:
#
# 1. Neste vestibular, quem 'zera' em matemática, física ou química está desqualificado. Monte um novo *DataFrame* com os alunos desqualificados por este critério.
# 2. Quantos são esses alunos?
# 3. Qual a média desses alunos em história e geografia?
# 4. Monte um *DataFrame* com os alunos que passaram para a segunda fase. Repare que estes alunos não podem ter sido desqualificados.

# %%
# seu código aqui
df_desqu = pd.concat([df_mat, df_fis, df_qui], axis=1)
df_desqu = df_desqu.drop('media', axis=1)
df_desqu.columns = ['Matematica', 'Fisica', 'Quimica']
df_desqu.loc[(df_desqu['Matematica'] == 0) |  (df_desqu['Fisica']==0) | (df_desqu['Quimica']==0), 'Desqualificado'] = 1
df_desqu.loc[(df_desqu['Matematica'] != 0) &  (df_desqu['Fisica']!=0) & (df_desqu['Quimica']!=0), 'Desqualificado'] = 0
df_desqu = df_desqu[df_desqu['Desqualificado'] == 1]
df_desqu
# Out:
#     Matematica  Fisica  Quimica  Desqualificado
# 3           10       0        8             1.0
# 6            6       0        4             1.0
# 10          10       7        0             1.0
# 12          20       0        3             1.0
# 14           7       4        0             1.0
# 20          23       2        0             1.0
# 25           0       4        8             1.0
# 26          11       0        0             1.0
# 27          21       3        0             1.0
# 33          14       6        0             1.0
# 35          11       0       11             1.0
# 49           8       0        8             1.0
# 56           7       0        8             1.0
# 65           1       0        6             1.0
# 66           5       0       10             1.0
# 72          11       0        9             1.0
# 73           1       0       11             1.0
# 74           9       7        0             1.0
# 84          15       0        4             1.0
# ...

# %%
#quantidade de alunos desqualificados
len(df_desqu)
# Out:
# 23

# %%
df_desqu['Media Historia'] = df_his.loc[df_desqu.index, ['media']]
df_desqu['Media Geografia'] = df_geo.loc[df_desqu.index, ['media']]
df_desqu
# Out:
#     Matematica  Fisica  Quimica  Desqualificado  Media Historia  \
# 3           10       0        8             1.0           0.000
# 6            6       0        4             1.0           0.625
# 10          10       7        0             1.0           0.125
# 12          20       0        3             1.0           0.125
# 14           7       4        0             1.0           0.125
# 20          23       2        0             1.0           0.750
# 25           0       4        8             1.0           0.000
# 26          11       0        0             1.0           0.875
# 27          21       3        0             1.0           0.875
# 33          14       6        0             1.0           0.750
# 35          11       0       11             1.0           0.375
# 49           8       0        8             1.0           0.125
# 56           7       0        8             1.0           0.750
# 65           1       0        6             1.0           0.375
# ...

# %%
df_tot_acert['Desqualificado'] = df_desqu.loc[df_desqu.index, 'Desqualificado']
df_tot_acert.loc[df_tot_acert['Desqualificado'] != 1, 'Desqualificado'] = 0 
df_tot_acert.loc[df_tot_acert['Desqualificado'] != 1, 'Desqualificado'] = 0 
df_tot_acert
# Out:
#     Total de Acertos  Porcentual Geral  Resultado  Desqualificado
# 0                 35          0.388889  Reprovado             0.0
# 1                 48          0.533333   Aprovado             0.0
# 2                 50          0.555556   Aprovado             0.0
# 3                 32          0.355556  Reprovado             1.0
# 4                 30          0.333333  Reprovado             0.0
# ..               ...               ...        ...             ...
# 95                34          0.377778  Reprovado             0.0
# 96                27          0.300000  Reprovado             0.0
# 97                40          0.444444  Reprovado             0.0
# 98                40          0.444444  Reprovado             1.0
# 99                42          0.466667  Reprovado             0.0
#
# [100 rows x 4 columns]

# %%
df_tot_acert.loc[(df_tot_acert['Desqualificado'] != 1) & (df_tot_acert['Resultado'] != 'Reprovado') , 'Passou de Fase'] = 1
df_tot_acert = df_tot_acert[df_tot_acert['Passou de Fase'] == 1]
df_tot_acert
# Out:
#     Total de Acertos  Porcentual Geral Resultado  Desqualificado  \
# 1                 48          0.533333  Aprovado             0.0
# 2                 50          0.555556  Aprovado             0.0
# 5                 50          0.555556  Aprovado             0.0
# 7                 49          0.544444  Aprovado             0.0
# 8                 58          0.644444  Aprovado             0.0
# 17                52          0.577778  Aprovado             0.0
# 18                50          0.555556  Aprovado             0.0
# 24                50          0.555556  Aprovado             0.0
# 31                54          0.600000  Aprovado             0.0
# 34                45          0.500000  Aprovado             0.0
# 36                56          0.622222  Aprovado             0.0
# 37                52          0.577778  Aprovado             0.0
# 39                49          0.544444  Aprovado             0.0
# ...

# %% [markdown]
# ## 3) Vacinações no Acre
# Vamos trabalhar agora com a base de vacinações no Acre. Para facilitar a sua vida, copiamos o link do arquivo na célula abaixo.
#
# 1. Quantas vacinas estão registradas nessa base?
# 2. Quantos pacientes foram vacinados? (considere um paciente para cada valor único de ```paciente_id```)
# 3. Quantos pacientes únicos tomaram a primeira dose? OBS: Há um caractere especial neste campo. Receba os valores do campo com o método ```.unique()```.
# 4. Quantos pacientes com menos de 18 anos foram vacinados?
# 5. Quantos estabelecimentos aplicaram vacina no Acre?
#
#
# **OBS:** O portal do DATASUS pode apresentar instabilidades, retornando um erro na segunda célula abaixo. Por este motivo está disponível uma base estática, que se for baixada para o seu *working directory* pode ser lida com este comando: ```df = pd.read_csv('registros de vacinacao covid ACRE.csv', sep=';')```.
#
# **OBS2:** Para saber qual é o seu working directory, rode no jupyter: ```!pwd```.

# %%
arquivo = 'https://s3.sa-east-1.amazonaws.com/ckan.saude.gov.br/SIPNI/COVID/uf/uf%3DAC/part-00000-e6de47be-4325-4762-8325-185cdeaf1fc1.c000.csv'

# %%
df = pd.read_csv(arquivo, sep=';')

# %%
df.info
# Out:
# <bound method DataFrame.info of                                       document_id  \
# 0       17d77df2-36dd-4731-894c-7a73c9ae5e0a-i0b0
# 1       e652ba21-51df-44cb-89dc-78fef2430461-i0b0
# 2       4aeb10a7-44df-4d37-9dce-7191fd140c93-i0b0
# 3       e69289ab-7f47-451e-a149-6ed6756b8de3-i0b0
# 4       8891c298-cf73-45cd-97e1-78d73dc51c9c-i0b0
# ...                                           ...
# 387273  ea845874-dc86-4b09-a0c9-b89d459f402c-i0b0
# 387274  ea9cdb0f-24be-4810-b90f-efb730b4ed0b-i0b0
# 387275  eaa1f757-f896-4c37-b296-38cd35886ec9-i0b0
# 387276  eaa5ee2a-1628-4056-90de-d811ac704df7-i0b0
# 387277  eac01189-20b3-45e1-bbf5-ae36ba05e267-i0b0
#
#                                               paciente_id  paciente_idade  \
# 0       ff44c7b6b1cc9ef7bcd2628f8c9ff0a4f80ad8eb47df96...              50
# 1       ee11da8e9f0e390507854ce43eb8eb5180f15abe612412...              22
# 2       693e2f28ee7874ff739c7e275c40f4fe41fcfa152b7521...              15
# ...

# %%
# 1) Sua solução aqui
df['vacina_fabricante_nome'].nunique()
# Out:
# 13

# %%
# 2)paciente_id
df['paciente_id'].nunique()
# Out:
# 316598

# %%
# 3)vacina_descricao_dose

df[df['vacina_descricao_dose']=='1ª Dose'].nunique()
# Out:
# document_id                                 143577
# paciente_id                                 143253
# paciente_idade                                 111
# paciente_dataNascimento                      29616
# paciente_enumSexoBiologico                       2
# paciente_racaCor_codigo                          6
# paciente_racaCor_valor                           6
# paciente_endereco_coIbgeMunicipio              927
# paciente_endereco_coPais                         4
# paciente_endereco_nmMunicipio                  923
# paciente_endereco_nmPais                         4
# paciente_endereco_uf                            28
# paciente_endereco_cep                         1937
# paciente_nacionalidade_enumNacionalidade         3
# estabelecimento_valor                          200
# estabelecimento_razaoSocial                     56
# estalecimento_noFantasia                       208
# estabelecimento_municipio_codigo                22
# ...

# %%
# 3) solução alternativa
df_copy = df[df['vacina_descricao_dose']=='1ª Dose']
df_copy['vacina_descricao_dose'].count()
# Out:
# 143577

# %%
# 4)
df_copy = df[df['paciente_idade']<18]
df_copy['paciente_idade'].count()
# Out:
# 77399

# %%
# 5)  
df['estalecimento_noFantasia'].nunique()
# Out:
# 232

# %% [markdown]
# ## 4) Vacinação II
# Gere um *DataFrame* que contenha somente os estabelecimentos que aplicaram vcinas a menores de 18 anos. Nesse *DataFrame* devem conter somente os dados dos estabelecimentos, mais uma coluna sendo a quantidade de vacinas que o estabelecimento aplicou a menores de 18 anos.
#
# 1. crie uma cópia do *DataFrame* original, contendo somente os registros de vacinas realizadas a menores de 18 anos.
# 2. crie uma lista das colunas desse *DataFrame* com o atributo de *DataFrame* **.columns()**
# 3. Nesse *DataFrame* faça uma contagem do campo ```vacina_categoria_nome```.
# 3. a partir da lista de colunas, escolha somente aquelas que são referentes ao estabelecimento, faça uma lista com esses valores.
# 4. usando o método *.loc*, selecione somente essas variáveis
# 5. Aplique o método **.drop_duplicates** e crie uma lista com uma linha para cada estabelecimento, com os dados do estabelecimento

# %%
# 1)
df_copy = df[df['paciente_idade']<18].copy()
df_copy
# Out:
#                                       document_id  \
# 2       4aeb10a7-44df-4d37-9dce-7191fd140c93-i0b0
# 5       e6a81814-15b0-46db-abb0-2319c447487a-i0b0
# 12      b3f369e2-91ba-4ca8-8214-f8daf9dbafd8-i0b0
# 15      e730f9c5-1f43-4b35-b209-4bb30f595117-i0b0
# 23      e75780d8-1314-4ab7-880d-bacac975b635-i0b0
# ...                                           ...
# 387261  e935a57b-2945-41dc-9168-c2b2307d23d0-i0b0
# 387266  e9c9e3c7-6ed2-4441-b1cc-a9c198a8bb10-i0b0
# 387268  ea21fb0c-4b24-4d31-8a05-ed255cd0d994-i0b0
# 387273  ea845874-dc86-4b09-a0c9-b89d459f402c-i0b0
# 387274  ea9cdb0f-24be-4810-b90f-efb730b4ed0b-i0b0
#
#                                               paciente_id  paciente_idade  \
# 2       693e2f28ee7874ff739c7e275c40f4fe41fcfa152b7521...              15
# 5       fdaee255d4202595956f0a96b189c6a74b9e5249019edf...               7
# 12      3926417c1e8266533eb9873614478b3cedcece1a05ff09...              12
# ...

# %%
# 2)
lista_colunas = df_copy.columns
lista_colunas
# Out:
# Index(['document_id', 'paciente_id', 'paciente_idade',
#        'paciente_dataNascimento', 'paciente_enumSexoBiologico',
#        'paciente_racaCor_codigo', 'paciente_racaCor_valor',
#        'paciente_endereco_coIbgeMunicipio', 'paciente_endereco_coPais',
#        'paciente_endereco_nmMunicipio', 'paciente_endereco_nmPais',
#        'paciente_endereco_uf', 'paciente_endereco_cep',
#        'paciente_nacionalidade_enumNacionalidade', 'estabelecimento_valor',
#        'estabelecimento_razaoSocial', 'estalecimento_noFantasia',
#        'estabelecimento_municipio_codigo', 'estabelecimento_municipio_nome',
#        'estabelecimento_uf', 'vacina_grupoAtendimento_codigo',
#        'vacina_grupoAtendimento_nome', 'vacina_categoria_codigo',
#        'vacina_categoria_nome', 'vacina_lote', 'vacina_fabricante_nome',
#        'vacina_fabricante_referencia', 'vacina_dataAplicacao',
#        'vacina_descricao_dose', 'vacina_codigo', 'vacina_nome',
#        'sistema_origem'],
# ...

# %%
# 3)vacina_categoria_nome
df_copy['vacina_categoria_nome'].nunique()
# Out:
# 13

# %%
# 4)
lista_colunas[14:21]
# Out:
# Index(['estabelecimento_valor', 'estabelecimento_razaoSocial',
#        'estalecimento_noFantasia', 'estabelecimento_municipio_codigo',
#        'estabelecimento_municipio_nome', 'estabelecimento_uf',
#        'vacina_grupoAtendimento_codigo'],
#       dtype='object')

# %%
# 5)
df_copy = df_copy.loc[:,lista_colunas[14:21]]

# %%
df_copy
# Out:
#         estabelecimento_valor  \
# 2                     2002922
# 5                     5354072
# 12                    6430201
# 15                    2002906
# 23                    6430201
# ...                       ...
# 387261                2000571
# 387266                6917682
# 387268                2001217
# 387273                7139454
# 387274                2002132
#
#                               estabelecimento_razaoSocial  \
# 2                           SECRETARIA MUNICIPAL DE SAUDE
# 5                          PREFEITURA MUNICIPAL DE JORDAO
# 12        DISTRITO SANITARIO ESPECIAL INDIGENA ALTO JURUA
# 15                       PREFEITURA MUNICIPAL DE CAPIXABA
# 23        DISTRITO SANITARIO ESPECIAL INDIGENA ALTO JURUA
# ...                                                   ...
# 387261            PREFEITURA MUNICIPAL DE CRUZEIRO DO SUL
# 387266  DISTRITO SANITARIO ESPECIAL INDIGENA ALTO RIO ...
# 387268                     PREFEITURA MUNICIPAL DE XAPURI
# ...

# %%
df_copy.drop_duplicates(inplace=True)

# %%
df_copy
# Out:
#         estabelecimento_valor  \
# 2                     2002922
# 5                     5354072
# 12                    6430201
# 15                    2002906
# 23                    6430201
# ...                       ...
# 379910                2000156
# 380755                2000040
# 384077                7565089
# 384290                6934013
# 386465                7959087
#
#                             estabelecimento_razaoSocial  \
# 2                         SECRETARIA MUNICIPAL DE SAUDE
# 5                        PREFEITURA MUNICIPAL DE JORDAO
# 12      DISTRITO SANITARIO ESPECIAL INDIGENA ALTO JURUA
# 15                     PREFEITURA MUNICIPAL DE CAPIXABA
# 23      DISTRITO SANITARIO ESPECIAL INDIGENA ALTO JURUA
# ...                                                 ...
# 379910                 PREFEITURA MUNICIPAL DE TARAUACA
# 380755                    PREFEITURA MUNICIPAL DE FEIJO
# 384077               PREFEITURA MUNICIPAL DE RIO BRANCO
# ...

# %%
lista_final = df_copy.values.tolist()
lista_final
# Out:
# [[2002922,
#   'SECRETARIA MUNICIPAL DE SAUDE',
#   'U S F JOAO DE DEUS',
#   120038,
#   'PLACIDO DE CASTRO',
#   'AC',
#   206],
#  [5354072,
#   'PREFEITURA MUNICIPAL DE JORDAO',
#   'UNIDADE DE SAUDE DA FAMILIA ANTONIO RODRIGUES DOURADO',
#   120032,
#   'JORDAO',
#   'AC',
#   207],
#  [6430201,
#   'DISTRITO SANITARIO ESPECIAL INDIGENA ALTO JURUA',
#   'POLO BASE INDIGENA',
#   120032,
#   'JORDAO',
#   'AC',
#   703],
#  [2002906,
#   'PREFEITURA MUNICIPAL DE CAPIXABA',
#   'CENTRO DE SAUDE IDELFONSO CORDEIRO DE ANDRADE',
#   120017,
#   'CAPIXABA',
#   'AC',
#   210],
#  [6430201,
#   'DISTRITO SANITARIO ESPECIAL INDIGENA ALTO JURUA',
#   'POLO BASE INDIGENA',
#   120032,
#   'JORDAO',
#   'AC',
#   701],
#  [6917291,
#   'PREFEITURA MUNICIPAL DE RIO BRANCO',
#   'DEPARTAMENTO DE VIGILANCIA EPIDEMIOLOGICA E AMBIENTAL',
#   120040,
#   'RIO BRANCO',
#   'AC',
#   210],
#  [6159087,
#   'PREFEITURA MUNICIPAL DE CRUZEIRO DO SUL',
# ...
